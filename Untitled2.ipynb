# %% [markdown]
# Install Libraries.

# %%
# !pip install fuzzywuzzy

import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/akankshasingh2gr8/name_correction_with_fuzzy_logic/main/company_data.csv'
df = pd.read_csv(url)
print(df)
# Out:
#             Company Name         Region        Brand        Category
# 0         Tech Solutions  North America     Innovate     Electronics
# 1         Tech Solutions         Europe     Innovate     Electronics
# 2         Global Imports           Asia        Elite         Apparel
# 3         Global Imports  South America        Elite         Apparel
# 4           Data Systems         Africa      Pioneer        Software
# 5           Data Systems    Middle East      Pioneer        Software
# 6      Energy Innovators  North America     EcoPower          Energy
# 7      Energy Innovators        Oceania     EcoPower          Energy
# 8   InnoTech Enterprises  South America     InnoGear     Electronics
# 9   InnoTech Enterprises         Europe     InnoGear     Electronics
# 10      Pacific Ventures           Asia      Oceanic  Consumer Goods
# 11      Pacific Ventures    Middle East      Oceanic  Consumer Goods
# 12    MegaTech Solutions         Africa     MegaTech      Technology
# ...

# %% [markdown]
# Simlarly, load data to be tested.

# %%
url2 = 'https://raw.githubusercontent.com/akankshasingh2gr8/name_correction_with_fuzzy_logic/main/data_to_test.csv'
df2 = pd.read_csv(url2)
print(df2)
# Out:
#                     Company Name         Region        Brand        Category
# 0           Data Systems Pvt Ltd  North America     Innovate     Electronics
# 1               Data Systems Inc         Europe        Elite         Apparel
# 2           Data Systems Limited           Asia      Pioneer        Software
# 3   Data Systems Private Limited  South America     EcoPower          Energy
# 4                   Data Systems         Europe     InnoGear     Electronics
# 5               Data Systems PVT    Middle East      Oceanic  Consumer Goods
# 6     Data Systems International         Africa     MegaTech      Technology
# 7         Data Systems Solutions  North America    GreenLife      Healthcare
# 8           Dynamic Data Systems        Oceania  DynamicGear     Electronics
# 9                   Dynamic Data    Middle East    AlphaTech      Technology
# 10              Tech Innovations  South America     Innovate     Electronics
# ...

# %% [markdown]
# ```
# # Define function to get best match
# ```

# %%
from fuzzywuzzy import process

# Function to find the best match for a company name in the generated data
def find_best_match(company_name, choices):
    return process.extractOne(company_name, choices)
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
all_choices = df['Company Name']
filtered_region_choice = all_choices[df['Region'] == ]

# %% [markdown]
# Apply fuzzyLogic to df2 ( client data )

# %%
df2['BestMatch'] = df2['Company Name'].apply(lambda x: find_best_match(x, choices ))
df2
# Out:
#                     Company Name         Region        Brand        Category  \
# 0           Data Systems Pvt Ltd  North America     Innovate     Electronics
# 1               Data Systems Inc         Europe        Elite         Apparel
# 2           Data Systems Limited           Asia      Pioneer        Software
# 3   Data Systems Private Limited  South America     EcoPower          Energy
# 4                   Data Systems         Europe     InnoGear     Electronics
# 5               Data Systems PVT    Middle East      Oceanic  Consumer Goods
# 6     Data Systems International         Africa     MegaTech      Technology
# 7         Data Systems Solutions  North America    GreenLife      Healthcare
# 8           Dynamic Data Systems        Oceania  DynamicGear     Electronics
# 9                   Dynamic Data    Middle East    AlphaTech      Technology
# 10              Tech Innovations  South America     Innovate     Electronics
# ...
